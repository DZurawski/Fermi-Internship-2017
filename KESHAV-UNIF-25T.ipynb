# %% [markdown]
# # Model Testing
# - Author: Daniel Zurawski, Keshav Kapoor
# - Organization: Fermilab
# - Grammar: Python 3.6.1

# %%
# !nvidia-smi
# Out:
# Fri Aug 18 13:42:11 2017
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 375.66                 Driver Version: 375.66                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1080    Off  | 0000:04:00.0     Off |                  N/A |
# | 27%   28C    P8     9W / 180W |    925MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 1080    Off  | 0000:05:00.0     Off |                  N/A |
# | 27%   29C    P8     9W / 180W |   7831MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce GTX 1080    Off  | 0000:06:00.0     Off |                  N/A |
# | 27%   27C    P8     9W / 180W |    557MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 1080    Off  | 0000:07:00.0     Off |                  N/A |
# | 27%   26C    P8     9W / 180W |    557MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   4  GeForce GTX 1080    Off  | 0000:0B:00.0     Off |                  N/A |
# | 27%   28C    P8     9W / 180W |   7749MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   5  GeForce GTX 1080    Off  | 0000:0C:00.0     Off |                  N/A |
# | 27%   31C    P8     9W / 180W |   7623MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   6  GeForce GTX 1080    Off  | 0000:0D:00.0     Off |                  N/A |
# | 27%   30C    P8     9W / 180W |      2MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   7  GeForce GTX 1080    Off  | 0000:0E:00.0     Off |                  N/A |
# | 27%   28C    P8    10W / 180W |    313MiB /  8114MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID  Type  Process name                               Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# %matplotlib notebook
import importlib
import numpy as np
import pandas as pd
import keras
from keras.preprocessing.sequence import pad_sequences
from keras.layers import TimeDistributed, Dense, Dropout, GRU, Bidirectional
from keras.models import Sequential
from tracker3d import loader, utils, metrics
# Out:
# Using Theano backend.
# Using cuDNN version 5110 on context None
# Mapped name None to device cuda: GeForce GTX 1080 (0000:04:00.0)

# %% [markdown]
# ## Loading in Data

# %%
# %%time
histories    = []
modelpath    = "models/KESHAV-UNIF-25T-1000E-PRZ-10N.h5"
order        = ("phi", "r", "z")
code         = (order[0][0] + order[1][0] + order[2][0]).upper()
n_noise      = 10
num_classes  = (25 + 2)
input_shape  = ((25 * 9) + n_noise, 3)
train_data, train_target = loader.from_file("datasets/npz/UNIF-25T-1000E-PRZ-10N.npz")
test_data,  test_target  = loader.from_file("datasets/npz/RAMP-PRZ-10N.npz")
print("train_data: {0}, train_target: {1}".format(train_data.shape, train_target.shape))
print("test_data: {0}, test_target: {1}".format(test_data.shape, test_target.shape))
# Out:
# train_data: (25000, 235, 3), train_target: (25000, 235, 27)
# test_data: (3600, 235, 3), test_target: (3600, 235, 27)
# CPU times: user 5.55 s, sys: 452 ms, total: 6 s
# Wall time: 6.13 s

# %% [markdown]
# ## Display an Example of the Data

# %%
e = 3435
print("Event Number {}".format(e))
utils.display_side_by_side(test_data[e], test_target[e], order=order)
# Out:
# Event Number 3435
# <table style=border:10px white-space:nowrap><tr style=border:10px white-space:nowrap><td nowrap='nowrap' style=border:10px white-space:nowrap><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>phi</th>
#       <th>r</th>
#       <th>z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-3.110905</td>
#       <td>271.0</td>
#       <td>86.296356</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-3.109980</td>
#       <td>155.0</td>
#       <td>-5.971339</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>
td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>-1.860917</td>
#       <td>562.0</td>
#       <td>85.571724</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>-1.841334</td>
#       <td>762.0</td>
#       <td>102.982750</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>-1.827948</td>
#       <td>762.0</td>
#       <td>58.860893</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>-1.805046</td>
#       <td>562.0</td>
#       <td>75.953156</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>-1.776660</td>
#       <td>405.0</td>
#       <td>54.734928</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>-1.774174</td>
#       <td>562.0</td>
#       <td>43.411839</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>-1.752668</td>
#       <td>271.0</td>
#       <td>36.625099</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>-1.742832</td>
#       <td>213.0</td>
#       <td>28.786518</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>-1.731763</td>
#       <td>155.0</td>
#       <td>20.947935</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>-1.731475</td>
#       <td>405.0</td>
#       <td>31.284332</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>-1.718516</td>
#       <td>85.0</td>
#       <td>11.487577</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>-1.716396</td>
#       <td>1000.0</td>
#       <td>-163.739792</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>-1.708293</td>
#       <td>39.0</td>
#       <td>5.270771</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>-1.695842</td>
#       <td>271.0</td>
#       <td>20.933468</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>-1.690612</td>
#       <td>762.0</td>
#       <td>116.024292</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>-1.680860</td>
#       <td>213.0</td>
#       <td>16.453241</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>-1.671124</td>
#       <td>762.0</td>
#       <td>-124.769722</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>-1.666441</td>
#       <td>155.0</td>
#       <td>11.973017</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>-1.647928</td>
#       <td>85.0</td>
#       <td>6.565848</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>-1.636500</td>
#       <td>39.0</td>
#       <td>3.012565</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>-1.632361</td>
#       <td>562.0</td>
#       <td>-92.021759</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>-1.601105</td>
#       <td>405.0</td>
#       <td>-66.314613</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>-1.575824</td>
#       <td>271.0</td>
#       <td>-44.373482</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>-1.564664</td>
#       <td>213.0</td>
#       <td>-34.876575</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>-1.553377</td>
#       <td>155.0</td>
#       <td>-25.379667</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>-1.537635</td>
#       <td>85.0</td>
#       <td>-13.917882</td>
#     </t

# %%
utils.plot3d(test_data[e], test_target[e], order=order, title="Event {}".format(e), flat_ax="z")
utils.plot3d(test_data[e], test_target[e], order=order, title="Event {}".format(e), flat_ax="r")
utils.plot3d(test_data[e], test_target[e], order=order, title="Event {}".format(e), flat_ax=None)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Defining the Neural Network Model

# %%
# For reloading the model.
model = keras.models.load_model(modelpath)
# Out:
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'

# %%
model = Sequential()
model.add(Bidirectional(
    GRU(
        units=256,
        return_sequences=True,
        recurrent_dropout=0.4,
        implementation=2),
    input_shape=input_shape,
    merge_mode="mul"))
model.add(Dropout(0.4))
for _ in range(2):
    model.add(Bidirectional(
        GRU(
            units=256, 
            return_sequences=True, 
            recurrent_dropout=0.4, 
            implementation=2),
        merge_mode="mul"))
    model.add(Dropout(0.4))
model.add(TimeDistributed(Dense(num_classes, activation='softmax')))

model.compile(loss='categorical_crossentropy', optimizer="rmsprop", metrics=['accuracy'])
model.summary()

# %% [markdown]
# ## Fitting the Neural Network Model

# %%
# %%time
# So far, has been fitted on 60 epochs
epochs     = 32
batch_size = 32
histories.append(model.fit(
    train_data,
    train_target,
    epochs=epochs,
    batch_size=batch_size,
    verbose=1,
    validation_data=(test_data, test_target),
    callbacks=[keras.callbacks.ModelCheckpoint(
        filepath=modelpath,
        save_best_only=True,
        verbose=0
    )]
))
# Out:
# Train on 25000 samples, validate on 3600 samples
# Epoch 1/32
# 25000/25000 [==============================] - 686s - loss: 0.3895 - acc: 0.8753 - val_loss: 0.1945 - val_acc: 0.9426
# Epoch 2/32
# 25000/25000 [==============================] - 681s - loss: 0.3976 - acc: 0.8732 - val_loss: 0.1865 - val_acc: 0.9455
# Epoch 3/32
# 25000/25000 [==============================] - 683s - loss: 0.3902 - acc: 0.8760 - val_loss: 0.1857 - val_acc: 0.9458
# Epoch 4/32
# 25000/25000 [==============================] - 676s - loss: 0.3841 - acc: 0.8778 - val_loss: 0.1878 - val_acc: 0.9457
# Epoch 5/32
# 25000/25000 [==============================] - 677s - loss: 0.3841 - acc: 0.8779 - val_loss: 0.1801 - val_acc: 0.9469
# Epoch 6/32
# 25000/25000 [==============================] - 693s - loss: 0.3852 - acc: 0.8776 - val_loss: 0.1859 - val_acc: 0.9453
# Epoch 7/32
# 25000/25000 [==============================] - 683s - loss: 0.3893 - acc: 0.8769 - val_loss: 0.1916 - val_acc: 0.9448
# Epoch 8/32
# 25000/25000 [==============================] - 690s - loss: 0.3989 - acc: 0.8730 - val_loss: 0.1985 - val_acc: 0.9423
# Epoch 9/32
# 25000/25000 [==============================] - 690s - loss: 0.4109 - acc: 0.8697 - val_loss: 0.1944 - val_acc: 0.9437
# Epoch 10/32
# 25000/25000 [==============================] - 686s - loss: 0.4106 - acc: 0.8693 - val_loss: 0.1993 - val_acc: 0.9409
# Epoch 11/32
# 25000/25000 [==============================] - 703s - loss: 0.4139 - acc: 0.8684 - val_loss: 0.2006 - val_acc: 0.9407
# Epoch 12/32
# 25000/25000 [==============================] - 681s - loss: 0.4291 - acc: 0.8630 - val_loss: 0.2062 - val_acc: 0.9390
# Epoch 13/32
# 25000/25000 [==============================] - 685s - loss: 0.4391 - acc: 0.8593 - val_loss: 0.2162 - val_acc: 0.9360
# Epoch 14/32
# 25000/25000 [==============================] - 674s - loss: 0.5014 - acc: 0.8367 - val_loss: 0.2257 - val_acc: 0.9314
# Epoch 15/32
# 25000/25000 [==============================] - 668s - loss: 0.5502 - acc: 0.8184 - val_loss: 0.2469 - val_acc: 0.9251
# Epoch 16/32
# 25000/25000 [==============================] - 671s - loss: 0.6101 - acc: 0.7957 - val_loss: 0.2637 - val_acc: 0.9183
# Epoch 17/32
# 25000/25000 [==============================] - 673s - loss: 0.6184 - acc: 0.7920 - val_loss: 0.3039 - val_acc: 0.9042
# Epoch 18/32
# 25000/25000 [==============================] - 666s - loss: 0.7125 - acc: 0.7528 - val_loss: 0.3441 - val_acc: 0.8908
# Epoch 19/32
# 25000/25000 [==============================] - 666s - loss: 0.7870 - acc: 0.7199 - val_loss: 0.3952 - val_acc: 0.8709
# Epoch 20/32
# 25000/25000 [==============================] - 671s - loss: 0.8449 - acc: 0.6979 - val_loss: 0.4651 - val_acc: 0.8234
# Epoch 21/32
# 25000/25000 [==============================] - 668s - loss: 0.8374 - acc: 0.6972 - val_loss: 0.4733 - val_acc: 0.8280
# Epoch 22/32
# 25000/25000 [==============================] - 668s - loss: 0.8957 - acc: 0.6767 - val_loss: 0.5341 - val_acc: 0.7995
# Epoch 23/32
# 25000/25000 [==============================] - 667s - loss: 0.8733 - acc: 0.6815 - val_loss: 0.5057 - val_acc: 0.8158
# Epoch 24/32
# 25000/25000 [==============================] - 669s - loss: 0.8379 - acc: 0.6918 - val_loss: 0.4572 - val_acc: 0.8323
# Epoch 25/32
# 25000/25000 [==============================] - 676s - loss: 0.7875 - acc: 0.7119 - val_loss: 0.4166 - val_acc: 0.8663
# Epoch 26/32
# 25000/25000 [==============================] - 667s - loss: 0.7506 - acc: 0.7250 - val_loss: 0.3778 - val_acc: 0.8712
# Epoch 27/32
# 25000/25000 [==============================] - 670s - loss: 0.6989 - acc: 0.7476 - val_loss: 0.3347 - val_acc: 0.8957
# Epoch 28/32
# 25000/25000 [==============================] - 675s - loss: 0.6284 - acc: 0.7794 - val_loss: 0.2901 - val_acc: 0.9114
# Epoch 29/32
# 25000/25000 [==============================] - 676s - loss: 0.6103 - acc: 0.7895 - val_loss: 0.2790 - val_acc: 0.9156
# Epoch 30/32
# 25000/25000 [==============================] - 676s - loss: 0.6486 - acc: 0.7746 - val_loss: 0.3171 - val_acc: 0.8999
# Epoch 31/32
# 25000/25000 [==============================] - 671s - loss: 0.6914 - acc: 0.7556 - val_loss: 0.3716 - val_acc: 0.8780
# Epoch 32/32
# 25000/25000 [==============================] - 666s - loss: 0.7272 - acc: 0.7381 - val_loss: 0.3672 - val_acc: 0.8811
# CPU times: user 5h 59min 34s, sys: 1min 43s, total: 6h 1min 18s
# Wall time: 6h 1min 6s

# %% [markdown]
# ## Plots of Predictions

# %%
utils.graph_losses([("", i) for i in histories])
import pickle
with open('25T-HISTORY', 'wb') as f:
        pickle.dump([h.history for h in histories], f)

# %%
guesses = model.predict(test_data)
print("Discrete Accuracy: {}".format(metrics.discrete_accuracy_all(test_data, guesses, test_target)))
# Out:
# Discrete Accuracy: 0.8654338702478275

# %%
discrete_acc = metrics.discrete_accuracy(guesses[e], test_target[e])
print("Event {0}: Discrete Accuracy {1}".format(e, discrete_acc))
utils.display_side_by_side(test_data[e], guesses[e], test_target[e], order=order)
# Out:
# Event 3435: Discrete Accuracy 0.4973544973544973
# <table style=border:10px white-space:nowrap><tr style=border:10px white-space:nowrap><td nowrap='nowrap' style=border:10px white-space:nowrap><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>phi</th>
#       <th>r</th>
#       <th>z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>
td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>-1.893196</td>
#       <td>1000.0</td>
#       <td>77.245270</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>-1.884296</td>
#       <td>1000.0</td>
#       <td>135.147964</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>-1.860917</td>
#       <td>562.0</td>
#       <td>85.571724</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>-1.841334</td>
#       <td>762.0</td>
#       <td>102.982750</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>-1.827948</td>
#       <td>762.0</td>
#       <td>58.860893</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>-1.805046</td>
#       <td>562.0</td>
#       <td>75.953156</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>-1.776660</td>
#       <td>405.0</td>
#       <td>54.734928</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>-1.774174</td>
#       <td>562.0</td>
#       <td>43.411839</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>-1.752668</td>
#       <td>271.0</td>
#       <td>36.625099</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>-1.742832</td>
#       <td>213.0</td>
#       <td>28.786518</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>-1.731763</td>
#       <td>155.0</td>
#       <td>20.947935</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>-1.731475</td>
#       <td>405.0</td>
#       <td>31.284332</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>-1.718516</td>
#       <td>85.0</td>
#       <td>11.487577</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>-1.716396</td>
#       <td>1000.0</td>
#       <td>-163.739792</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>-1.708293</td>
#       <td>39.0</td>
#       <td>5.270771</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>-1.695842</td>
#       <td>271.0</td>
#       <td>20.933468</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>-1.690612</td>
#       <td>762.0</td>
#       <td>116.024292</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>-1.680860</td>
#       <td>213.0</td>
#       <td>16.453241</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>-1.671124</td>
#       <td>762.0</td>
#       <td>-124.769722</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>-1.666441</td>
#       <td>155.0</td>
#       <td>11.973017</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>-1.647928</td>
#       <td>85.0</td>
#       <td>6.565848</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>-1.636500</td>
#       <td>39.0</td>
#       <td>3.012565</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>-1.632361</td>
#       <td>562.0</td>
#       <td>-92.021759</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>-1.601105</td>
#       <td>405.0</td>
#       <td>-66.314613</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>-1.575824</td>
#       <td>271.0</td>
#       <td>-44.373482</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>-1.564664</td>
#       <td>213.0</td>
#       <td>-34.876575</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>-1.553377</td>
#       <td>155.0</td>
#       <td>-25.379667</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>-1.537635</td>
#       <td>85.0</td>
#       <td>-13.917882</td>
#     </t

# %%
utils.plot3d(test_data[e], guesses[e], test_target[e], order=order, title="Event {}".format(e), flat_ax="z")
#utils.plot3d(test_data[e], guesses[e], test_target[e], order=order, title="Event {}".format(e), flat_ax="r")
#utils.plot3d(test_data[e], guesses[e], test_target[e], order=order, title="Event {}".format(e), flat_ax=None)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
thresholds = [i / 10 for i in range(1, 1 + 10)]
_ = metrics.accuracy_vs_tracks_boxplot(guesses, test_target, noise=True)
_ = metrics.threshold_boxplot(guesses, test_target, thresholds, variation="correct")
_ = metrics.threshold_boxplot(guesses, test_target, thresholds, variation="incorrect")
_ = metrics.threshold_boxplot(guesses, test_target, thresholds, variation="many")
_ = metrics.threshold_boxplot(guesses, test_target, thresholds, variation="none")
# Out:
# <img src="data:image/png;base64,..." width="955.4285714285714">
# <img src="data:image/png;base64,..." width="915.8095238095239">
# <img src="data:image/png;base64,..." width="917.3333333333334">
# <img src="data:image/png;base64,..." width="925.7142857142857">
# <img src="data:image/png;base64,..." width="928.7619047619048">
