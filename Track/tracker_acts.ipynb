# %%
# System imports
import ast

# Data handling
import numpy as np
import pandas as pd

# Machine learning
from keras import layers, models

# Visualization
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Local imports
from data import load_data_events
from metrics import calc_hit_accuracy
from drawing import draw_projections
from drawing import draw_3d_event

# %matplotlib notebook
# Out:
# Using Theano backend.
# Using cuDNN version 5105 on context None
# Mapped name None to device cuda: GeForce GTX 1080 (0000:0D:00.0)

# %%
def process_hits_data(df, copy_keys=['evtid', 'barcode', 'volid', 'layid']):
    """Split columns and calculate some derived variables"""
    #hits = pd.DataFrame(df[copy_keys])
    x = df.gpos.apply(lambda pos: pos[0])
    y = df.gpos.apply(lambda pos: pos[1])
    z = df.gpos.apply(lambda pos: pos[2])
    r = np.sqrt(x**2 + y**2)
    phi = np.arctan2(y, x)
    return df[copy_keys].assign(z=z, r=r, phi=phi)

def process_particles_data(df, copy_keys=['evtid', 'barcode', 'q']):
    """Split columns and calculate some derived variables"""
    #particles = pd.DataFrame(df[copy_keys])
    p = df.kin.apply(lambda kin: kin[0])
    theta = df.kin.apply(lambda kin: kin[1])
    phi = df.kin.apply(lambda kin: kin[2])
    pt = p * np.sin(theta)
    eta = -1. * np.log(np.tan(theta / 2.))
    return df[copy_keys].assign(pt=pt, eta=eta, phi=phi)

# %%
hits_file_name = '/bigdata/shared/Fermi_tmp_folder/cluster.csv'


# Read and prepare the hits data
hits_columns = ['hitid', 'barcode', 'volid', 'layid',
                'lpos', 'lerr', 'gpos',
                'chans', 'dir', 'direrr']
hits = process_hits_data(
    load_data_events(hits_file_name, columns=hits_columns, print_freq=200))

# Select all barrel hits
barrel_hits = hits[(hits.volid == 8) | (hits.volid == 13) | (hits.volid == 17)]

# Select target tracks that have 8 or more hits in the barrel
signal_tracks = (barrel_hits.groupby(['evtid', 'barcode'])
                 .filter(lambda x: len(x) > 8)
                 .groupby(['evtid', 'barcode']))
# Out:
# Loading /bigdata/shared/Fermi_tmp_folder/cluster.csv
# Finished event 0
# Finished event 200
# Finished event 400
# Finished event 600
# Finished event 800
# Finished event 1000
# Finished event 1200
# Finished event 1400
# Finished event 1600
# Finished event 1800
# Finished event 2000
# Finished event 2200
# Finished event 2400
# Finished event 2600
# Finished event 2800
# Finished event 3000
# Finished event 3200
# Finished event 3400
# Finished event 3600
# Finished event 3800
# Finished event 4000
# Finished event 4200
# Finished event 4400
# Finished event 4600
# Finished event 4800
# Finished event 5000
# Finished event 5200
# Finished event 5400
# Finished event 5600
# Finished event 5800
# Finished event 6000
# Finished event 6200
# Finished event 6400
# Finished event 6600
# Finished event 6800
# Finished event 7000
# Finished event 7200
# Finished event 7400
# Finished event 7600
# Finished event 7800
# Finished event 8000
# Finished event 8200
# Finished event 8400
# Finished event 8600
# Finished event 8800
# Finished event 9000
# Finished event 9200
# Finished event 9400
# Finished event 9600
# Finished event 9800
# Finished event 10000
# Finished event 10200
# Finished event 10400
# Finished event 10600
# Finished event 10800
# Finished event 11000
# Finished event 11200
# Finished event 11400
# Finished event 11600
# Finished event 11800
# Finished event 12000
# Finished event 12200
# Finished event 12400
# Finished event 12600
# Finished event 12800
# Finished event 13000
# Finished event 13200
# Finished event 13400
# Finished event 13600
# Finished event 13800
# Finished event 14000
# Finished event 14200
# Finished event 14400
# Finished event 14600
# Finished event 14800
# Finished event 15000
# Finished event 15200
# Finished event 15400
# Finished event 15600
# Finished event 15800
# Finished event 16000
# Finished event 16200
# Finished event 16400
# Finished event 16600
# Finished event 16800
# Finished event 17000
# Finished event 17200
# Finished event 17400
# Finished event 17600
# Finished event 17800
# Finished event 18000
# Finished event 18200
# Finished event 18400
# Finished event 18600
# Finished event 18800
# Finished event 19000
# Finished event 19200
# Finished event 19400
# Finished event 19600
# Finished event 19800
# Finished event 20000
# Finished event 20200
# Finished event 20400
# Finished event 20600
# Finished event 20800
# Finished event 21000
# Finished event 21200
# Finished event 21400
# Finished event 21600
# Finished event 21800
# Finished event 22000
# Finished event 22200
# Finished event 22400
# Finished event 22600
# Finished event 22800
# Finished event 23000
# Finished event 23200
# Finished event 23400
# Finished event 23600
# Finished event 23800
# Finished event 24000
# Finished event 24200
# Finished event 24400
# Finished event 24600
# Finished event 24800
# Finished event 25000
# Finished event 25200
# Finished event 25400
# Finished event 25600
# Finished event 25800
# Finished event 26000
# Finished event 26200
# Finished event 26400
# Finished event 26600
# Finished event 26800
# Finished event 27000
# Finished event 27200
# Finished event 27400
# Finished event 27600
# Finished event 27800
# Finished event 28000
# Finished event 28200
# Finished event 28400
# Finished event 28600
# Finished event 28800
# Finished event 29000
# Finished event 29200
# Finished event 29400
# Finished event 29600
# Finished event 29800
# Finished event 30000
# Finished event 30200
# Finished event 30400
# Finished event 30600
# Finished event 30800
# Finished event 31000
# Finished event 31200
# Finished event 31400
# Finished event 31600
# Finished event 31800
# Finished event 32000
# Finished event 32200
# Finished event 32400
# Finished event 32600
# Finished event 32800
# Finished event 33000
# Finished event 33200
# Finished event 33400
# Finished event 33600
# Finished event 33800
# Finished event 34000
# Finished event 34200
# Finished event 34400
# Finished event 34600
# Finished event 34800
# Finished event 35000
# Finished event 35200
# Finished event 35400
# Finished event 35600
# Finished event 35800
# Finished event 36000
# Finished event 36200
# Finished event 36400
# Finished event 36600
# Finished event 36800
# Finished event 37000
# Finished event 37200
# Finished event 37400
# Finished event 37600
# Finished event 37800
# Finished event 38000
# Finished event 38200
# Finished event 38400
# Finished event 38600
# Finished event 38800
# Finished event 39000
# Finished event 39200
# Finished event 39400
# Finished event 39600
# Finished event 39800
# Finished event 40000
# Finished event 40200
# Finished event 40400
# Finished event 40600

# %%
print('Hits data shape:', hits.shape)
print(signal_tracks.ngroups)

print('Example hit:')
#print(hits.head(1))
print(barrel_hits.head(1))
#print(signal_tracks.head(1))

barrel_hits.to_csv('/bigdata/shared/Fermi_tmp_folder/test_new.csv', sep=' ')
# Out:
# Hits data shape: (29516502, 7)
# 1177296
# Example hit:
#     evtid           barcode  volid  layid       phi          r        z
# 11      0  9013658885554176      8      2  3.116947  33.605406 -246.297
